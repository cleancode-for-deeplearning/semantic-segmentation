# %% [markdown]
# <a href="https://colab.research.google.com/github/EON-LEE/CLEANCODE_WITH_PYTHON/blob/master/pytorch_custom_dataset_le.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://lmb.informatik.uni-freiburg.de/resources/datasets/bio/data/BMMCdata.tar.bz2 --no-check-certificate
# !wget https://lmb.informatik.uni-freiburg.de/resources/datasets/bio/data/BMMCmasks.tar.bz2 --no-check-certificate
# Out:
# --2020-05-27 01:12:05--  https://lmb.informatik.uni-freiburg.de/resources/datasets/bio/data/BMMCdata.tar.bz2
# Resolving lmb.informatik.uni-freiburg.de (lmb.informatik.uni-freiburg.de)... 132.230.167.23
# Connecting to lmb.informatik.uni-freiburg.de (lmb.informatik.uni-freiburg.de)|132.230.167.23|:443... connected.
# WARNING: cannot verify lmb.informatik.uni-freiburg.de's certificate, issued by ‘CN=DFN-Verein Global Issuing CA,OU=DFN-PKI,O=Verein zur Foerderung eines Deutschen Forschungsnetzes e. V.,C=DE’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 34393518 (33M) [application/x-bzip2]
# Saving to: ‘BMMCdata.tar.bz2’
#
# BMMCdata.tar.bz2    100%[===================>]  32.80M   908KB/s    in 15s
#
# 2020-05-27 01:12:20 (2.26 MB/s) - ‘BMMCdata.tar.bz2’ saved [34393518/34393518]
#
# --2020-05-27 01:12:22--  https://lmb.informatik.uni-freiburg.de/resources/datasets/bio/data/BMMCmasks.tar.bz2
# Resolving lmb.informatik.uni-freiburg.de (lmb.informatik.uni-freiburg.de)... 132.230.167.23
# Connecting to lmb.informatik.uni-freiburg.de (lmb.informatik.uni-freiburg.de)|132.230.167.23|:443... connected.
# WARNING: cannot verify lmb.informatik.uni-freiburg.de's certificate, issued by ‘CN=DFN-Verein Global Issuing CA,OU=DFN-PKI,O=Verein zur Foerderung eines Deutschen Forschungsnetzes e. V.,C=DE’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 228573 (223K) [application/x-bzip2]
# Saving to: ‘BMMCmasks.tar.bz2’
#
# BMMCmasks.tar.bz2   100%[===================>] 223.22K   544KB/s    in 0.4s
#
# 2020-05-27 01:12:24 (544 KB/s) - ‘BMMCmasks.tar.bz2’ saved [228573/228573]

# %%
# !ls
# Out:
# BMMCdata.tar.bz2  BMMCmasks.tar.bz2  sample_data

# %%
# !bunzip2 BMMCdata.tar.bz2 BMMCmasks.tar.bz2

# %%
# !ls
# Out:
# BMMCdata.tar  BMMCmasks.tar  sample_data

# %%
# !tar -xvf BMMCdata.tar 
# !tar -xvf BMMCmasks.tar
# Out:
# data/
# data/BMMC_54.tif
# data/BMMC_53.tif
# data/BMMC_52.tif
# data/BMMC_51.tif
# data/BMMC_50.tif
# data/BMMC_49.tif
# data/BMMC_48.tif
# data/BMMC_46.tif
# data/BMMC_45.tif
# data/BMMC_44.tif
# data/BMMC_43.tif
# data/BMMC_42.tif
# data/BMMC_41.tif
# data/BMMC_40.tif
# data/BMMC_39.tif
# data/BMMC_38.tif
# data/BMMC_37.tif
# data/BMMC_36.tif
# data/BMMC_35.tif
# data/BMMC_34.tif
# data/BMMC_28.tif
# data/BMMC_27.tif
# data/BMMC_26.tif
# data/BMMC_25.tif
# data/BMMC_24.tif
# data/BMMC_23.tif
# data/BMMC_22.tif
# data/BMMC_21.tif
# data/BMMC_20.tif
# data/BMMC_18.tif
# data/BMMC_17.tif
# data/BMMC_16.tif
# data/BMMC_15.tif
# data/BMMC_14.tif
# data/BMMC_13.tif
# data/BMMC_12.tif
# data/BMMC_11.tif
# data/BMMC_10.tif
# data/BMMC_7.tif
# data/BMMC_6.tif
# data/BMMC_4.tif
# data/BMMC_2.tif
# data/BMMC_1.tif
# masks/
# masks/BMMC_7.tif_segmentation.tifnomalized.tif
# masks/BMMC_6.tif_segmentation.tifnomalized.tif
# masks/BMMC_54.tif_segmentation.tifnomalized.tif
# masks/BMMC_53.tif_segmentation.tifnomalized.tif
# masks/BMMC_52.tif_segmentation.tifnomalized.tif
# masks/BMMC_51.tif_segmentation.tifnomalized.tif
# masks/BMMC_50.tif_segmentation.tifnomalized.tif
# masks/BMMC_49.tif_segmentation.tifnomalized.tif
# masks/BMMC_48.tif_segmentation.tifnomalized.tif
# masks/BMMC_46.tif_segmentation.tifnomalized.tif
# masks/BMMC_45.tif_segmentation.tifnomalized.tif
# masks/BMMC_44.tif_segmentation.tifnomalized.tif
# masks/BMMC_43.tif_segmentation.tifnomalized.tif
# masks/BMMC_42.tif_segmentation.tifnomalized.tif
# masks/BMMC_41.tif_segmentation.tifnomalized.tif
# masks/BMMC_40.tif_segmentation.tifnomalized.tif
# masks/BMMC_4.tif_segmentation.tifnomalized.tif
# masks/BMMC_39.tif_segmentation.tifnomalized.tif
# masks/BMMC_38.tif_segmentation.tifnomalized.tif
# masks/BMMC_37.tif_segmentation.tifnomalized.tif
# masks/BMMC_36.tif_segmentation.tifnomalized.tif
# masks/BMMC_35.tif_segmentation.tifnomalized.tif
# masks/BMMC_34.tif_segmentation.tifnomalized.tif
# masks/BMMC_28.tif_segmentation.tifnomalized.tif
# masks/BMMC_27.tif_segmentation.tifnomalized.tif
# masks/BMMC_26.tif_segmentation.tifnomalized.tif
# masks/BMMC_25.tif_segmentation.tifnomalized.tif
# masks/BMMC_24.tif_segmentation.tifnomalized.tif
# masks/BMMC_23.tif_segmentation.tifnomalized.tif
# masks/BMMC_22.tif_segmentation.tifnomalized.tif
# masks/BMMC_21.tif_segmentation.tifnomalized.tif
# masks/BMMC_20.tif_segmentation.tifnomalized.tif
# masks/BMMC_2.tif_segmentation.tifnomalized.tif
# masks/BMMC_18.tif_segmentation.tifnomalized.tif
# masks/BMMC_17.tif_segmentation.tifnomalized.tif
# masks/BMMC_16.tif_segmentation.tifnomalized.tif
# masks/BMMC_15.tif_segmentation.tifnomalized.tif
# masks/BMMC_14.tif_segmentation.tifnomalized.tif
# masks/BMMC_13.tif_segmentation.tifnomalized.tif
# masks/BMMC_12.tif_segmentation.tifnomalized.tif
# masks/BMMC_11.tif_segmentation.tifnomalized.tif
# masks/BMMC_10.tif_segmentation.tifnomalized.tif
# masks/BMMC_1.tif_segmentation.tifnomalized.tif

# %%
# !ls
# Out:
# BMMCdata.tar  BMMCmasks.tar  data  masks  sample_data

# %%
import torch
from torch.utils.data.dataset import Dataset 
from torchvision import transforms
from PIL import Image
import glob

folder_data = sorted(glob.glob("./data/*.tif"))
folder_mask = sorted(glob.glob("./masks/*.tif"))

len_data = len(folder_data)
train_size = 0.7

train_image_paths = folder_data[:int(len_data*train_size)]
test_image_paths = folder_data[int(len_data*train_size):]

train_mask_paths = folder_mask[:int(len_data*train_size)]
test_mask_paths = folder_mask[int(len_data*train_size):]

class CustomDataset(Dataset):
    def __init__(self, image_paths, target_paths, train=True):   

        self.image_paths = image_paths
        self.target_paths = target_paths
        self.transforms = transforms.ToTensor()

    def __getitem__(self, index):

        image = Image.open(self.image_paths[index])
        mask = Image.open(self.target_paths[index])
        t_image = self.transforms(image)
        return t_image, mask

    def __len__(self):  

        return len(self.image_paths)

train_dataset = CustomDataset(train_image_paths, train_mask_paths, train=True)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=False)

test_dataset = CustomDataset(test_image_paths, test_mask_paths, train=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
import torchvision.transforms.functional as tf
from matplotlib import pyplot as plt

for check_dataset in train_dataset:

    image, mask = check_dataset
    layer, height, width = (image.size())

    image = tf.to_pil_image(image)  

    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize = (6,6))
                        
    img1 = ax1.imshow(image, cmap='gray')
    ax1.axis('on')   

    img2 = ax2.imshow(mask)
    ax2.axis('on')        
    plt.show()
